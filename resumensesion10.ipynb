# %% [markdown]
# <a href="https://colab.research.google.com/github/AngieCuevas12/Resumen-de-clases/blob/main/resumensesion10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  El dia de hoy vimos dos videos, el primero trato sobre flutter apprentice el cual ayuda a guiarnos desde inbstalar las herramientas, hasta diseñar con widgets, conectar datos, usar firebase y finalmente lanzar tu app en las 2 tiendas m,as grandes con un solo codigo. En el segundo video se trataba sobre como la solucion para crear apps moviles sin duplicar copdigo, tambien se hablo que su mayor ventajaj es la velocidada el hot reload el cual deja ver cambios en la interfaz al instante sin perder el estado y si se necesita reiniciar todo solo se puede utilizar hot restart.
